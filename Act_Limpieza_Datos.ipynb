# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-team_59/blob/main/Act_Limpieza_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 3 - Actividad 1
#
# *Andrea Margarita Osorio González*
#
# *A01104776*
#
# *Ciencia y analítica de datos (Gpo 10)*
#
# *Jobish Vallikavungal Devassia & Orlando Figón Cruz*
#
# *29 de septiembre de 2022*
#
#
# **Parte 1: Fundamentos de bases de datos**
# Las bases de datos son bancos de información almacenada que fungen como almacenes de fuentes adversas de donde se recopila dicha información.
# Esta información sirve para el análisis de toma de decisiones, sin embargo, para llevar a cabo este análisis se debe seguir un proceso científico de datos:
# •	Definición del problema
# •	Recolección de datos y preparación
# •	Desarrollo e implementación de un modelo
# •	Mejorar el rendimiento
# Para lograr un conjunto de datos se debe realizar una limpieza y pre-procesamiento exhaustiva de la información para asegurar tener un conjunto de datos de calidad con información relevante que debe ser validada previa a lanzar un modelo.
# El preprocesamiento consiste en transformar datos incomprensibles a comprensibles, en los datos que cuentan con discrepancias o errores, este proceso se lleva a cabo con la limpieza, transformación y reducción de datos.
#
# **Parte 2: Selección y limpieza de los Datos en Python**
# Act_Limpieza_Datos.ipynb - Colaboratory (google.com)
# Se realizó una limpieza de datos, se recopiló la información vacía, se descartaron los datos con valores faltantes, se eliminaron los datos vacíos, se sustituyeron valores vacíos de acuerdo a los datos de la media de una misma variable, se eliminaron columnas y se sustituyeron nombres de columnas.
#
#
# **Parte 3: Preparación de los datos**
# 1.	¿Qué datos considero más importantes? ¿Por qué?
# Todos los datos con valores son importantes porque mejoran la calidad para el análisis y así se asegura el tener un análisis adecuado, sin embargo los datos relevantes siempre dependerán de las necesidades del análisis.
#
#
# 2.	¿Se eliminaron o reemplazaron datos nulos? ¿Qué se hizo y por qué?
# En la primera parte se muestra un ejercicio en donde se eliminaron porque los datos nulos no nos sirven para hacer análisis de información tan fidedigna
# En la segunda parte se reemplazaron los valores de acuerdo con la moda.
# Esto con el objetivo de evitar resultados sesgados o conclusiones invalidas.
#
#
# 3.	¿Es necesario ordenar los datos para el análisis? Sí / No / ¿Por qué?
# Si para tener una mejor visión de los datos y poder analizarlos con un mejor entendimiento y permite una mejor capacidad de respuesta y un análisis efectivo.
#
#
# 4.	¿Existen problemas de formato que deban solucionar antes del proceso de modelado? Sí / No / Por qué.
# Si, se debe hacer una limpieza efectiva, transformación y reducción de datos faltantes  para mejorar el desempeño del proceso y contar con datos de calidad que permitan tomar decisiones más informadas y poder realizar el modelado correctamente.
#
#
# 5.	¿Qué ajustes se realizaron en el proceso de limpieza de datos (agregar, integrar, eliminar, modificar registros (filas), cambiar atributos (columnas)?
# •	Revisión de datos nulos
# •	Eliminar columnas
# •	Llenar/modificar valores
# •	Cambiar nombres de columnas

# %%
import pandas as pd
import numpy as np

# %%
x = {'Company': ['Ford', 'Ford', 'VW', 'BMW', 'Cooper', 'Cooper'], 
     'Stars' : [1, 2, np.nan, 2, 1, 1], 
     'Weight' : [2, 4, 2, 2, 3, None], 
     'Origin' : ['China', 'Mexico', 'Mexico', None, 'China', np.nan], 
     'Length': [40, 50, 30, np.nan, 45, pd.NaT]
}

# %%
df  = pd.DataFrame(data = x)
df
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0  Mexico     50
# 2      VW    NaN     2.0  Mexico     30
# 3     BMW    2.0     2.0    None    NaN
# 4  Cooper    1.0     3.0   China     45
# 5  Cooper    1.0     NaN     NaN    NaT

# %%
df.to_csv("data.csv")

# %%
df=pd.read_csv("/content/data.csv",index_col=0)
df
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
df.isna().values.any()
# Out:
# True

# %%
df.isna().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
df.isna().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
df
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
df.dropna(inplace=True)

# %%
df.isna().values.any()
# Out:
# False

# %%
df
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 4  Cooper    1.0     3.0   China    45.0

# %%
df=pd.read_csv("/content/data.csv",index_col=0)
df.isna().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.dropna(axis=1,inplace=True)
ndf
# Out:
#   Company
# 0    Ford
# 1    Ford
# 2      VW
# 3     BMW
# 4  Cooper
# 5  Cooper

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.dropna(how="all",inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.dropna(thresh=4,inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 4  Cooper    1.0     3.0   China    45.0

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.dropna(thresh=5,
           axis=1,
           inplace=True)
ndf
# Out:
#   Company  Stars  Weight
# 0    Ford    1.0     2.0
# 1    Ford    2.0     4.0
# 2      VW    NaN     2.0
# 3     BMW    2.0     2.0
# 4  Cooper    1.0     3.0
# 5  Cooper    1.0     NaN

# %%
SOLUCIÓN 2

# %%
ndf=df.copy()

# %%
wm=ndf.Weight.mean()
wm
# Out:
# 2.6

# %%
ndf["Weight"].fillna(value=wm,
                     inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     2.6     NaN     NaN

# %%
ndf["Length"].fillna(value=ndf.Length.median(),
                     inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN    42.5
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     2.6     NaN    42.5

# %%
mm=ndf.Origin.mode()
mm
# Out:
# 0     China
# 1    Mexico
# dtype: object

# %%
mm[1]
# Out:
# 'Mexico'

# %%
ndf["Origin"].fillna(value=mm[1],
                     inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0  Mexico    42.5
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     2.6  Mexico    42.5

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.dropna(subset=["Origin","Length"],inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 4  Cooper    1.0     3.0   China    45.0

# %%
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.Origin.mode()[0]
# Out:
# 'China'

# %%
favs={"Origin":ndf.Origin.mode()[0],"Length":ndf["Length"].mean()}

# %%
ndf.Origin.fillna(ndf.Origin.mode()[0],inplace=True)
ndf.Length.fillna(ndf.Length.mean(),inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China   40.00
# 1    Ford    2.0     4.0  Mexico   50.00
# 2      VW    NaN     2.0  Mexico   30.00
# 3     BMW    2.0     2.0   China   41.25
# 4  Cooper    1.0     3.0   China   45.00
# 5  Cooper    1.0     NaN   China   41.25

# %% [markdown]
# Mediana vs Media

# %%
data={"Salary":[28,30,30,35,37,40,400]}
adf=pd.DataFrame(data)
adf
# Out:
#    Salary
# 0      28
# 1      30
# 2      30
# 3      35
# 4      37
# 5      40
# 6     400

# %%
adf.describe()
# Out:
#            Salary
# count    7.000000
# mean    85.714286
# std    138.653903
# min     28.000000
# 25%     30.000000
# 50%     35.000000
# 75%     38.500000
# max    400.000000

# %%
df=pd.read_csv("/content/data.csv",index_col=0)
ndf=df.copy()
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf.columns
# Out:
# Index(['Company', 'Stars', 'Weight', 'Origin', 'Length'], dtype='object')

# %%
ndf.columns.sort_values()
# Out:
# Index(['Company', 'Length', 'Origin', 'Stars', 'Weight'], dtype='object')

# %%
ndf.loc[2:5,"Company":"Origin"]
# Out:
#   Company  Stars  Weight  Origin
# 2      VW    NaN     2.0  Mexico
# 3     BMW    2.0     2.0     NaN
# 4  Cooper    1.0     3.0   China
# 5  Cooper    1.0     NaN     NaN

# %%
favs=["Stars","Weight","Origin"]

# %%
ndf.loc[2:5,favs]
# Out:
#    Stars  Weight  Origin
# 2    NaN     2.0  Mexico
# 3    2.0     2.0     NaN
# 4    1.0     3.0   China
# 5    1.0     NaN     NaN

# %%
ndf.iloc[2:5,[1,2,3]]
# Out:
#    Stars  Weight  Origin
# 2    NaN     2.0  Mexico
# 3    2.0     2.0     NaN
# 4    1.0     3.0   China

# %%
ndf.columns
# Out:
# Index(['Company', 'Stars', 'Weight', 'Origin', 'Length'], dtype='object')

# %%
for i in ndf.columns:
  print(i)
# Out:
# Company
# Stars
# Weight
# Origin
# Length

# %%
ndf.head(4)
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN

# %%
ndf.Company.unique()
# Out:
# array(['Ford', 'VW', 'BMW', 'Cooper'], dtype=object)

# %%
df.groupby(["Company","Origin"]).size()
# Out:
# Company  Origin
# Cooper   China     1
# Ford     China     1
#          Mexico    1
# VW       Mexico    1
# dtype: int64

# %%
df[["Company","Origin"]].value_counts()
# Out:
# Company  Origin
# Cooper   China     1
# Ford     China     1
#          Mexico    1
# VW       Mexico    1
# dtype: int64

# %% [markdown]
# Eliminar columnas/Cambiar nombre de columnas

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Length
# 0    Ford    1.0     2.0   China    40.0
# 1    Ford    2.0     4.0  Mexico    50.0
# 2      VW    NaN     2.0  Mexico    30.0
# 3     BMW    2.0     2.0     NaN     NaN
# 4  Cooper    1.0     3.0   China    45.0
# 5  Cooper    1.0     NaN     NaN     NaN

# %%
ndf2=ndf.drop(["Stars","Origin",],axis=1)
ndf2
# Out:
#   Company  Weight  Length
# 0    Ford     2.0    40.0
# 1    Ford     4.0    50.0
# 2      VW     2.0    30.0
# 3     BMW     2.0     NaN
# 4  Cooper     3.0    45.0
# 5  Cooper     NaN     NaN

# %%
ndf2.rename(columns={"Company":"Empresa","Weight":"Peso"},inplace=True)
ndf2
# Out:
#   Empresa  Peso  Length
# 0    Ford   2.0    40.0
# 1    Ford   4.0    50.0
# 2      VW   2.0    30.0
# 3     BMW   2.0     NaN
# 4  Cooper   3.0    45.0
# 5  Cooper   NaN     NaN

# %%
ndf2.rename(columns={"Length":"Largo"},inplace=True)
ndf2
# Out:
#   Empresa  Peso  Largo
# 0    Ford   2.0   40.0
# 1    Ford   4.0   50.0
# 2      VW   2.0   30.0
# 3     BMW   2.0    NaN
# 4  Cooper   3.0   45.0
# 5  Cooper   NaN    NaN
